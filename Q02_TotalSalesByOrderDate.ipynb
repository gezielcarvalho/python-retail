# %% [markdown]
# # Exploratory Data Analysis (EDA). Retail Industry
# ## Total sales for  order date

# %%
# Imports
from retail_analytics import (
    dataset_profile,
    load_retail_dataset,
    total_sales_by_order_date,
    lineplot,
)

# %% [markdown]
# ### Loading the dataset

# %%
# Load the dataset
dataframe_retail = load_retail_dataset()

# %% [markdown]
# ### Exploratory Analysis

# %%
# Dataset profile
profile = dataset_profile(dataframe_retail)
print("Dataset shape:", profile["shape"])
print("Missing values:", profile["nulls"].sum())

# %% [markdown]
# ### Calculate the total sales for each order date and visualize the results using a bar chart.

# %%
# Calculate total sales by order date
dataframe_retail_total_per_date = total_sales_by_order_date(dataframe_retail)

# %%
dataframe_retail_total_per_date.head()

# %%
# Create line plot
lineplot(
    dataframe_retail_total_per_date,
    x="OrderDate",
    y="TotalOrderValue",
    title="Total Sales per Order Date",
    figsize=(20, 6),
);
